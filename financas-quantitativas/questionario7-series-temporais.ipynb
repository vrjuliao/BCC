# %%
# MA(1) sigma=0.9
set.seed(12345)
ma1.model = list(ma=0.9)
mu = 1
set.seed(123)
ma1.sim = mu + arima.sim(model=ma1.model, n=250)
ma1.acf = ARMAacf(ar=0, ma=0.9, lag.max=10)

# AR(1) phi=0.9
set.seed(1245)
ar1.model = list(ar=0.9)
mu = 1
set.seed(1213)
ar1.sim = mu + arima.sim(model=ar1.model, n=250)
ar1.acf = ARMAacf(ar=0.5, ma=0, lag.max=10)


# ARMA(1, 1) phi=0.5 theta=0.9
arma11.model = list(ar=c(0.5), ma=c(0.9))
mu = 1
set.seed(128835)
arma11.sim = mu + arima.sim(model=arma11.model, n=250)
arma11.acf = ARMAacf(ar=0.5, ma=0.9, lag.max=10)

# %%
plot(acf(arma11.sim))
# Out:
# Plot with title “Series  arma11.sim”

# %%
plot(acf(ar1.sim))
# Out:
# Plot with title “Series  ar1.sim”

# %%
plot(acf(ma1.sim))
# Out:
# Plot with title “Series  ma1.sim”

# %%
# MA(2) theta=(0.9, 0.7)
set.seed(1235)
ma2.model = list(ma=c(0.9, 0.7))
mu = 1
set.seed(123)
ma2.sim = mu + arima.sim(model=ma2.model, n=250)

# AR(2) phi=(0.9, -0.6)
set.seed(12345)
ar2.model = list(ar=c(0.9, -0.6))
mu = 1
set.seed(123)
ar2.sim = mu + arima.sim(model=ar2.model, n=250)

# %%
plot(acf(ar2.sim))
# Out:
# Plot with title “Series  ar2.sim”

# %%
plot(acf(ma2.sim))
# Out:
# Plot with title “Series  ma2.sim”
